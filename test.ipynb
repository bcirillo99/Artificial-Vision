# %%
# Mount your Drive - After doing this step, your Google Drive folders are accessible from Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Install all the requirements
# !pip install opencv-python scikit-learn pillow pandas
# !pip install tensorflow==2.11.*

## We use a conda enviroment following the instruction in: https://www.tensorflow.org/install/pip

# %%
# Run the test
# --data is the file with the annotations. 
# --images is the path of the folder with the images listed in --data. 
# --results is the file on which the predictions of model should be written. 
# !python test.py --data GTA_CAIP_Contest_Code/foo_test.csv --images GTA_CAIP_Contest_Code/foo_test/ --results foo_results.csv
